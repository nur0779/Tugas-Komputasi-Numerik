# %% [markdown]
# <a href="https://colab.research.google.com/github/nur0779/Tugas-Komputasi-Numerik/blob/main/curve_fit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = 2 * x - 5 + rng.randn(50)
plt.scatter(x, y);

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y)

xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit[:, np.newaxis])

plt.scatter(x, y)
plt.plot(xfit, yfit);

# %%
print("Model slope:    ", model.coef_[0])
print("Model intercept:", model.intercept_)
# Out:
# Model slope:     2.0272088103606953
# Model intercept: -4.998577085553204

# %%
rng = np.random.RandomState(1)
x = 10 * rng.rand(50)
y = np.sin(x) + 0.1 * rng.randn(50)

plt.scatter(x, y)

# Definisi fungsi sinusoidal untuk curve fitting
def sinusoidal(x, A, B, C, D):
    return A * np.sin(B * x + C) + D

# Curve fitting untuk data sinusoidal
initial_guess = [1, 1, 0, 0]  # Tebakan awal untuk parameter [A, B, C, D]
params, covariance = curve_fit(sinusoidal, x2, y2, p0=initial_guess)

# Ekstrak parameter yang diestimasi
A, B, C, D = params
print("\nHasil Curve Fitting (Fungsi Sinusoidal):")
print(f"A (amplitudo): {A}")
print(f"B (frekuensi): {B}")
print(f"C (fase): {C}")
print(f"D (offset): {D}")

# Prediksi data menggunakan fungsi sinusoidal yang sesuai
xfit2 = np.linspace(0, 10, 1000)  # Membuat data x untuk plot
yfit2 = sinusoidal(xfit2, A, B, C, D)  # Prediksi y berdasarkan parameter yang diestimasi

# Plot scatter dan hasil curve fitting sinusoidal
plt.figure(figsize=(8, 6))
plt.scatter(x2, y2, label='Data Sinusoidal', color='green', alpha=0.7)
plt.plot(xfit2, yfit2, label='Fitting Fungsi Sinusoidal', color='orange', linewidth=2)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Curve Fitting Fungsi Sinusoidal')
plt.legend()
plt.show()
# Out:
# Hasil Curve Fitting (Fungsi Sinusoidal):
# A (amplitudo): 0.9989633848313056
# B (frekuensi): 1.0072917325134219
# C (fase): -0.02659815533325292
# D (offset): 0.018591077286072063
